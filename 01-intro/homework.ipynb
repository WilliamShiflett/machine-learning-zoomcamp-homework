# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Q1. Pandas version

# %%
print(pd.__version__)
# Out:
# 2.3.1

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')

# %% [markdown]
# Q2. Records count

# %%
print(len(df))
# Out:
# 9704

# %% [markdown]
# Q3. Fuel types

# %%
df['fuel_type'].unique()
# Out:
# array(['Gasoline', 'Diesel'], dtype=object)

# %% [markdown]
# Q4. Missing values

# %%
print(df.columns[df.isnull().any()])
len(df.columns[df.isnull().any()])
# Out:
# Index(['num_cylinders', 'horsepower', 'acceleration', 'num_doors'], dtype='object')
# 4

# %% [markdown]
# Q5. Max fuel efficiency

# %%
df[df['origin'] == 'Asia'].sort_values(by='fuel_efficiency_mpg', ascending=False)
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 9387                  330            3.0       136.0     1223.298226
# 343                   240            2.0         NaN     1652.883753
# 7739                  170           10.0       139.0     1491.755825
# 9401                  110            1.0       183.0     1707.231276
# 5416                  250            6.0       173.0     1354.787120
# ...                   ...            ...         ...             ...
# 2890                  240            4.0        92.0     4323.711871
# 9120                  180            3.0       181.0     4661.144932
# 6581                  150            NaN       148.0     4392.759292
# 3891                  290            6.0       145.0     4481.764226
# 1095                  210            6.0        93.0     4345.732510
#
#       acceleration  model_year origin fuel_type         drivetrain  num_doors  \
# ...

# %% [markdown]
# Q6. Median value of horsepower

# %%
median_original = df['horsepower'].median()
most_frequent_hp = df['horsepower'].mode()
filled_hp = df['horsepower'].fillna(most_frequent_hp[0])
median_new = filled_hp.median()
print('original median', median_original, 'new median',median_new)
# Out:
# original median 149.0 new median 152.0

# %% [markdown]
# Q7. Sum of weights

# %%
cars_from_asia = df[df['origin'] == 'Asia']
# print(cars_from_asia)
cars_from_asia_vw_my = cars_from_asia[['vehicle_weight', 'model_year']]
# print(cars_from_asia_vw_my)
first_7_rows = cars_from_asia_vw_my.head(7)
print(first_7_rows)
# Out:
#     vehicle_weight  model_year
# 8      2714.219310        2016
# 12     2783.868974        2010
# 14     3582.687368        2007
# 20     2231.808142        2011
# 21     2659.431451        2016
# 34     2844.227534        2014
# 38     3761.994038        2019

# %% [markdown]
# Get the underlying NumPy array. Let's call it X.

# %%
X = first_7_rows.values
print(X)
X_T = X.T
print(X_T)
XTX = X.dot(X_T)
# print(XTX)
XTX_inverse = np.linalg.inv(XTX)
# print(XTX_inverse.dot(XTX))
Y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
# Out:
# [[2714.21930965 2016.        ]
#  [2783.86897424 2010.        ]
#  [3582.68736772 2007.        ]
#  [2231.8081416  2011.        ]
#  [2659.43145076 2016.        ]
#  [2844.22753389 2014.        ]
#  [3761.99403819 2019.        ]]
# [[2714.21930965 2783.86897424 3582.68736772 2231.8081416  2659.43145076
#   2844.22753389 3761.99403819]
#  [2016.         2010.         2007.         2011.         2016.
#   2014.         2019.        ]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 10
#       8 # print(XTX_inverse.dot(XTX))
#       9 Y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
# ---> 10 print(X.dot(Y))
#      11 # print(Y)
#
# ValueError: shapes (7,2) and (7,) not aligned: 2 (dim 1) != 7 (dim 0)

# %%
matrix = np.array([[1, 2, 3],
                   [4, 5, 6]])

transposed_matrix = matrix.T
print(transposed_matrix)
# Out:
# [[1 4]
#  [2 5]
#  [3 6]]

# %% [markdown]
# Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
